# %% [markdown]
# # 1. Getting index data

# %% [markdown]
# some famous us-market indices are :
# * S&P 500 : ticker=^GSPC
# * Dow Jones : ticker=^DJI

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import time

# %%
tickers = ["^GSPC", "^DJI"]
indexes = yf.download(tickers, period='5y')
indexes
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price          Adj Close                      Close               \
# Ticker              ^DJI        ^GSPC          ^DJI        ^GSPC
# Date
# 2020-02-18  29232.189453  3370.290039  29232.189453  3370.290039
# 2020-02-19  29348.029297  3386.149902  29348.029297  3386.149902
# 2020-02-20  29219.980469  3373.229980  29219.980469  3373.229980
# 2020-02-21  28992.410156  3337.750000  28992.410156  3337.750000
# 2020-02-24  27960.800781  3225.889893  27960.800781  3225.889893
# ...                  ...          ...           ...          ...
# 2025-02-11  44593.648438  6068.500000  44593.648438  6068.500000
# 2025-02-12  44368.558594  6051.970215  44368.558594  6051.970215
# 2025-02-13  44711.429688  6115.069824  44711.429688  6115.069824
# 2025-02-14  44546.078125  6114.629883  44546.078125  6114.629883
# 2025-02-18  44438.921875  6120.419922  44438.921875  6120.419922
#
# ...

# %% [markdown]
# as for how the above data can be grouped according to ticker and make it more  usable : refet to 1.GettingStockDataFromYfinance. subarticle:8 group by ticker

# %%
# getting only closing data
tickers = ["^GSPC", "^DJI"]
indexes = yf.download(tickers, period='5y').Close
indexes
# Out:
# [*********************100%***********************]  2 of 2 completed
# Ticker              ^DJI        ^GSPC
# Date
# 2020-02-18  29232.189453  3370.290039
# 2020-02-19  29348.029297  3386.149902
# 2020-02-20  29219.980469  3373.229980
# 2020-02-21  28992.410156  3337.750000
# 2020-02-24  27960.800781  3225.889893
# ...                  ...          ...
# 2025-02-11  44593.648438  6068.500000
# 2025-02-12  44368.558594  6051.970215
# 2025-02-13  44711.429688  6115.069824
# 2025-02-14  44546.078125  6114.629883
# 2025-02-18  44438.921875  6120.419922
#
# [1258 rows x 2 columns]

# %%
indexes.iloc[0].mul(100)
# Out:
# Ticker
# ^DJI     2.923219e+06
# ^GSPC    3.370290e+05
# Name: 2020-02-18 00:00:00, dtype: float64

# %%
normalizedData = indexes.div(indexes.iloc[0]).mul(100)
normalizedData
# Out:
# Ticker            ^DJI       ^GSPC
# Date
# 2020-02-18  100.000000  100.000000
# 2020-02-19  100.396275  100.470579
# 2020-02-20   99.958234  100.087231
# 2020-02-21   99.179742   99.034503
# 2020-02-24   95.650724   95.715498
# ...                ...         ...
# 2025-02-11  152.549806  180.058687
# 2025-02-12  151.779800  179.568231
# 2025-02-13  152.952723  181.440462
# 2025-02-14  152.387074  181.427409
# 2025-02-18  152.020504  181.599205
#
# [1258 rows x 2 columns]

# %%
normalizedData.plot()
plt.show()

# %% [markdown]
# <b><u> and this process of normalization is universal i.e 2 or more assets may not be homogeneous i.e one can be equity , another can index, while another can be equity . thus this normaization is a pretty powerful tool that helps us to normalize and compare. </u></b>

# %% [markdown]
# # 2. Getting etfs and mutual fund data

# %%
etf = 'SPY'
yf.download(etf, period='1y')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Ticker             SPY         SPY         SPY         SPY         SPY
# Date
# 2024-02-20  490.468628  496.760010  498.410004  494.450012  497.720001
# 2024-02-21  490.912872  497.209991  497.369995  493.559998  495.420013
# 2024-02-22  501.072601  507.500000  508.489990  503.019989  504.010010
# 2024-02-23  501.418152  507.850006  510.130005  507.100006  509.269989
# 2024-02-26  499.581696  505.989990  508.750000  505.859985  508.299988
# ...                ...         ...         ...         ...         ...
# 2025-02-11  605.309998  605.309998  605.859985  602.429993  602.549988
# 2025-02-12  603.359985  603.359985  604.549988  598.510010  599.200012
# 2025-02-13  609.729980  609.729980  609.940002  603.200012  604.479980
# 2025-02-14  609.700012  609.700012  610.989990  609.070007  609.940002
# ...

# %%
fund = 'VTSAX'
yf.download(fund, period='1y')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open Volume
# Ticker           VTSAX       VTSAX       VTSAX       VTSAX       VTSAX  VTSAX
# Date
# 2024-02-20  118.558731  120.139999  120.139999  120.139999  120.139999      0
# 2024-02-21  118.598213  120.180000  120.180000  120.180000  120.180000      0
# 2024-02-22  120.966621  122.580002  122.580002  122.580002  122.580002      0
# 2024-02-23  121.045570  122.660004  122.660004  122.660004  122.660004      0
# 2024-02-26  120.710037  122.320000  122.320000  122.320000  122.320000      0
# ...                ...         ...         ...         ...         ...    ...
# 2025-02-10  145.970001  145.970001  145.970001  145.970001  145.970001      0
# 2025-02-11  145.860001  145.860001  145.860001  145.860001  145.860001      0
# 2025-02-12  145.419998  145.419998  145.419998  145.419998  145.419998      0
# ...

# %% [markdown]
# # 3. getting currency data

# %% [markdown]
# points to note:
# * it is to be noted that currencies trade in pairs
# * also currency values that we download are more precise after decimal place. [it can go anywhere between 6 to 10 decimal places]. since the comparison movements are very minute
# * currencies are also traded 24/7 in USA. however in india the market time for currency is not 24h

# %%
fx1 = "EURUSD=X"
fx2 = "EURJPY=X"

# %%
eurusd = yf.download(fx1, period="1y")
eurusd
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price      Adj Close     Close      High       Low      Open   Volume
# Ticker      EURUSD=X  EURUSD=X  EURUSD=X  EURUSD=X  EURUSD=X EURUSD=X
# Date
# 2024-02-19  1.078493  1.078493  1.078981  1.076299  1.078446        0
# 2024-02-20  1.077540  1.077540  1.083858  1.076252  1.077540        0
# 2024-02-21  1.081315  1.081315  1.082251  1.079191  1.081315        0
# 2024-02-22  1.082040  1.082040  1.088625  1.080509  1.082040        0
# 2024-02-23  1.082567  1.082567  1.083940  1.081373  1.082567        0
# ...              ...       ...       ...       ...       ...      ...
# 2025-02-12  1.036495  1.036495  1.039566  1.031821  1.036495        0
# 2025-02-13  1.039199  1.039199  1.044572  1.037926  1.039199        0
# 2025-02-14  1.046167  1.046167  1.051370  1.044812  1.046167        0
# 2025-02-17  1.048922  1.048922  1.050707  1.046737  1.048922        0
# ...

# %% [markdown]
# # 4. gettting crypto-currency data

# %%
ticker = ["BTC-USD","ETH-USD","SHIB-USD"]
df =yf.download(ticker, period='5y')
df
# Out:
# [*********************100%***********************]  3 of 3 completed
# Price          Adj Close                                Close               \
# Ticker           BTC-USD      ETH-USD  SHIB-USD       BTC-USD      ETH-USD
# Date
# 2020-02-18  10141.996094   281.944580       NaN  10141.996094   281.944580
# 2020-02-19   9633.386719   259.763977       NaN   9633.386719   259.763977
# 2020-02-20   9608.475586   257.949463       NaN   9608.475586   257.949463
# 2020-02-21   9686.441406   265.600616       NaN   9686.441406   265.600616
# 2020-02-22   9663.181641   262.331726       NaN   9663.181641   262.331726
# ...                  ...          ...       ...           ...          ...
# 2025-02-14  97508.968750  2726.091553  0.000017  97508.968750  2726.091553
# 2025-02-15  97580.351562  2693.559814  0.000016  97580.351562  2693.559814
# 2025-02-16  96175.031250  2663.315918  0.000016  96175.031250  2663.315918
# ...

# %%
#now lets get hold of the closing prices
cc = df.Close
cc
# Out:
# Ticker           BTC-USD      ETH-USD  SHIB-USD
# Date
# 2020-02-18  10141.996094   281.944580       NaN
# 2020-02-19   9633.386719   259.763977       NaN
# 2020-02-20   9608.475586   257.949463       NaN
# 2020-02-21   9686.441406   265.600616       NaN
# 2020-02-22   9663.181641   262.331726       NaN
# ...                  ...          ...       ...
# 2025-02-14  97508.968750  2726.091553  0.000017
# 2025-02-15  97580.351562  2693.559814  0.000016
# 2025-02-16  96175.031250  2663.315918  0.000016
# 2025-02-17  95773.382812  2743.199707  0.000016
# 2025-02-18  95713.757812  2692.850586  0.000015
#
# [1828 rows x 3 columns]

# %%
#lets quicly plot to get a comparison overview
cc.plot()
plt.show()

# %% [markdown]
# # 5. getting Treasury Yields data

# %%
ticker = ["^FVX","^TNX"]

# %%
yields = yf.download(ticker, period='5y')
yields
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price      Adj Close         Close          High           Low          Open  \
# Ticker          ^FVX   ^TNX   ^FVX   ^TNX   ^FVX   ^TNX   ^FVX   ^TNX   ^FVX
# Date
# 2020-02-18     1.393  1.556  1.393  1.556  1.406  1.576  1.375  1.541  1.378
# 2020-02-19     1.409  1.570  1.409  1.570  1.424  1.587  1.395  1.556  1.401
# 2020-02-20     1.370  1.525  1.370  1.525  1.395  1.548  1.352  1.507  1.382
# 2020-02-21     1.318  1.471  1.318  1.471  1.345  1.492  1.283  1.439  1.342
# 2020-02-24     1.218  1.377  1.218  1.377  1.250  1.402  1.192  1.352  1.246
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2025-02-11     4.370  4.537  4.370  4.537  4.382  4.547  4.361  4.525  4.370
# 2025-02-12     4.484  4.637  4.484  4.637  4.496  4.660  4.363  4.527  4.372
# 2025-02-13     4.386  4.525  4.386  4.525  4.484  4.619  4.377  4.515  4.453
# ...

# %%
yields = yields.Close
yields
# Out:
# Ticker       ^FVX   ^TNX
# Date
# 2020-02-18  1.393  1.556
# 2020-02-19  1.409  1.570
# 2020-02-20  1.370  1.525
# 2020-02-21  1.318  1.471
# 2020-02-24  1.218  1.377
# ...           ...    ...
# 2025-02-11  4.370  4.537
# 2025-02-12  4.484  4.637
# 2025-02-13  4.386  4.525
# 2025-02-14  4.324  4.472
# 2025-02-18  4.367  4.519
#
# [1258 rows x 2 columns]

# %%
yields.plot()
plt.show()

# %% [markdown]
# # 6. getting real-time data

# %%
df = yf.download("EURJPY=X", period='1d', interval='1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# to get display the last few records 
df.tail()
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                       EURJPY=X    EURJPY=X    EURJPY=X    EURJPY=X
# Datetime
# 2025-02-18 14:53:00+00:00  158.666000  158.666000  158.684998  158.658997
# 2025-02-18 14:54:00+00:00  158.682999  158.682999  158.688004  158.664993
# 2025-02-18 14:55:00+00:00  158.703003  158.703003  158.716003  158.684006
# 2025-02-18 14:56:00+00:00  158.707001  158.707001  158.723999  158.688004
# 2025-02-18 14:57:00+00:00  158.679993  158.679993  158.707993  158.677994
#
# Price                            Open   Volume
# Ticker                       EURJPY=X EURJPY=X
# Datetime
# 2025-02-18 14:53:00+00:00  158.671997        0
# 2025-02-18 14:54:00+00:00  158.664993        0
# 2025-02-18 14:55:00+00:00  158.684998        0
# 2025-02-18 14:56:00+00:00  158.705994        0
# 2025-02-18 14:57:00+00:00  158.705994        0

# %%
#to get the last index
print(df.index[-1])
# Out:
# 2025-02-18 14:57:00+00:00

# %%
#to print the last index and close price
print(df.index[-1], df.iloc[-1, 3]) 
#i.e. in iloc() we are passing the rowindex and the columnindex
# Out:
# 2025-02-18 14:57:00+00:00 158.67799377441406

# %% [markdown]
# now combining the above techniques we can get the latest data streamed as shown below.
# * here i have polled only 5 times using a counter
# * however to run this live streamer we can have an infinite while loop using while True
# * if we want the timer to run only during market hours when we have to write the while loop accordingly

# %%
counter = 5
while counter>0:
    time.sleep(1) # sleeping for 5 seconds
    data = yf.download("EURJPY=X", period='1d', interval='1m')
    print(data.index[-1], data.iloc[1,3])
    counter= counter-1
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2025-02-18 14:57:00+00:00 158.74899291992188
# [*********************100%***********************]  1 of 1 completed
# 2025-02-18 14:57:00+00:00 158.74899291992188
# [*********************100%***********************]  1 of 1 completed
# 2025-02-18 14:57:00+00:00 158.74899291992188
# [*********************100%***********************]  1 of 1 completed
# 2025-02-18 14:57:00+00:00 158.74899291992188
# [*********************100%***********************]  1 of 1 completed
# 2025-02-18 14:57:00+00:00 158.74899291992188

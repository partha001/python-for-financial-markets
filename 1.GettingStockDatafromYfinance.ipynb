# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing data from yahoo finance

# %% [markdown]
# # 1. Getting historical-data [i.e.  Open/high/low/close] using yfinance

# %% [markdown]
# ## getting historical data for a particular stock

# %%
# go to yahoo finance and find the symbol/ticker for the instrument
ticker = "TSLA"
yf.download(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2010-06-29    1.592667    1.592667    1.666667    1.169333    1.266667
# 2010-06-30    1.588667    1.588667    2.028000    1.553333    1.719333
# 2010-07-01    1.464000    1.464000    1.728000    1.351333    1.666667
# 2010-07-02    1.280000    1.280000    1.540000    1.247333    1.533333
# 2010-07-06    1.074000    1.074000    1.333333    1.055333    1.333333
# ...                ...         ...         ...         ...         ...
# 2025-02-10  350.730011  350.730011  362.700012  350.510010  356.209991
# 2025-02-11  328.500000  328.500000  349.369995  325.100006  345.799988
# 2025-02-12  336.510010  336.510010  346.399994  329.119995  329.940002
# 2025-02-13  355.940002  355.940002  358.690002  342.850006  345.000000
# ...

# %% [markdown]
# ## getting historical data for a given date-range

# %%
ticker = "TSLA"
start = '2020-01-01'
end = '2025-01-01'
yf.download(ticker,start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2020-01-02   28.684000   28.684000   28.713333   28.114000   28.299999
# 2020-01-03   29.534000   29.534000   30.266666   29.128000   29.366667
# 2020-01-06   30.102667   30.102667   30.104000   29.333332   29.364668
# 2020-01-07   31.270666   31.270666   31.441999   30.224001   30.760000
# 2020-01-08   32.809334   32.809334   33.232666   31.215334   31.580000
# ...                ...         ...         ...         ...         ...
# 2024-12-24  462.279999  462.279999  462.779999  435.140015  435.899994
# 2024-12-26  454.130005  454.130005  465.329987  451.019989  465.160004
# 2024-12-27  431.660004  431.660004  450.000000  426.500000  449.519989
# 2024-12-30  417.410004  417.410004  427.000000  415.750000  419.399994
# ...

# %% [markdown]
# ## getting historical data for multiple stocks

# %%
ticker = ["TSLA","GOOG"]
yf.download(ticker)
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price        Adj Close                   Close                    High  \
# Ticker            GOOG        TSLA        GOOG        TSLA        GOOG
# Date
# 2004-08-19    2.490186         NaN    2.499133         NaN    2.591785
# 2004-08-20    2.687981         NaN    2.697639         NaN    2.716817
# 2004-08-23    2.715032         NaN    2.724787         NaN    2.826406
# 2004-08-24    2.602609         NaN    2.611960         NaN    2.779581
# 2004-08-25    2.630652         NaN    2.640104         NaN    2.689918
# ...                ...         ...         ...         ...         ...
# 2025-02-10  188.199997  350.730011  188.199997  350.730011  189.990005
# 2025-02-11  187.070007  328.500000  187.070007  328.500000  188.800003
# 2025-02-12  185.429993  336.510010  185.429993  336.510010  186.830002
# 2025-02-13  187.880005  355.940002  187.880005  355.940002  187.990005
# ...

# %% [markdown]
# ## getting historical data for multiple stocks for a given date range

# %%
ticker = ["TSLA","GOOG"]
start = '2020-01-01'
end = '2025-01-01'
yf.download(ticker, start, end)
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price        Adj Close                   Close                    High  \
# Ticker            GOOG        TSLA        GOOG        TSLA        GOOG
# Date
# 2020-01-02   68.123726   28.684000   68.368500   28.684000   68.406998
# 2020-01-03   67.789421   29.534000   68.032997   29.534000   68.625000
# 2020-01-06   69.460922   30.102667   69.710503   30.102667   69.824997
# 2020-01-07   69.417580   31.270666   69.667000   31.270666   70.149498
# 2020-01-08   69.964615   32.809334   70.216003   32.809334   70.579002
# ...                ...         ...         ...         ...         ...
# 2024-12-24  197.570007  462.279999  197.570007  462.279999  197.669998
# 2024-12-26  197.100006  454.130005  197.100006  454.130005  198.160004
# 2024-12-27  194.039993  431.660004  194.039993  431.660004  196.800003
# 2024-12-30  192.690002  417.410004  192.690002  417.410004  193.779999
# ...

# %% [markdown]
# do shift + tab inside the yf.download() method to explore all the parameters.
# * ie. one can also pass a period as method parameter as 1d, 1m [m stands for min], 1mo [mo stands for month],10y , ytd (for year till date),etc

# %% [markdown]
# # 2. Getting intra-day data

# %% [markdown]
# ## getting intraday data for 1h interval

# %%
#for getting the intra-day data we will make use of the interval parameter of the yf.downloadl
#as shown below

#however it is to be kept in mind that when using the interval the duration can not extends beyond 
#last 60 days
ticker="ITC.NS"
#getting 1hr data for last 1hr
yf.download(ticker, period ='1mo', interval='1h')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                         ITC.NS      ITC.NS      ITC.NS      ITC.NS
# Datetime
# 2025-01-20 03:45:00+00:00  437.299988  437.299988  441.000000  436.549988
# 2025-01-20 04:45:00+00:00  437.100006  437.100006  438.399994  436.549988
# 2025-01-20 05:45:00+00:00  438.100006  438.100006  439.950012  436.950012
# 2025-01-20 06:45:00+00:00  436.899994  436.899994  438.350006  436.549988
# 2025-01-20 07:45:00+00:00  437.299988  437.299988  437.450012  436.000000
# ...                               ...         ...         ...         ...
# 2025-02-17 05:45:00+00:00  409.250000  409.250000  410.149994  409.000000
# 2025-02-17 06:45:00+00:00  406.799988  406.799988  409.250000  406.750000
# 2025-02-17 07:45:00+00:00  408.149994  408.149994  408.950012  406.750000
# 2025-02-17 08:45:00+00:00  408.750000  408.750000  409.350006  407.899994
# ...

# %% [markdown]
# ## getting intra-day data for 5min interval

# %%
# similarly getting 30min data for lat one month
yf.download(ticker, period='1mo', interval = '5m')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                         ITC.NS      ITC.NS      ITC.NS      ITC.NS
# Datetime
# 2025-01-20 03:45:00+00:00  439.950012  439.950012  441.000000  438.399994
# 2025-01-20 03:50:00+00:00  440.000000  440.000000  440.750000  439.549988
# 2025-01-20 03:55:00+00:00  438.250000  438.250000  439.600006  438.250000
# 2025-01-20 04:00:00+00:00  438.399994  438.399994  439.149994  438.399994
# 2025-01-20 04:05:00+00:00  438.000000  438.000000  438.600006  437.899994
# ...                               ...         ...         ...         ...
# 2025-02-17 09:35:00+00:00  408.850006  408.850006  409.000000  408.700012
# 2025-02-17 09:40:00+00:00  408.750000  408.750000  409.000000  408.549988
# 2025-02-17 09:45:00+00:00  408.500000  408.500000  408.750000  408.450012
# 2025-02-17 09:50:00+00:00  408.450012  408.450012  408.549988  408.049988
# ...

# %% [markdown]
# note that when we fetched data for 30min interval we got 161 records. however when we fetched 5min interval data we received 1725 records for the same duration i.e. 1month

# %% [markdown]
# ## getting intra-data for 1min interval

# %%
# getting 1min data for last 5days
yf.download(ticker, period='5d', interval='1m')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                         ITC.NS      ITC.NS      ITC.NS      ITC.NS
# Datetime
# 2025-02-11 03:45:00+00:00  429.250000  429.250000  430.149994  427.700012
# 2025-02-11 03:46:00+00:00  429.750000  429.750000  430.100006  429.000000
# 2025-02-11 03:47:00+00:00  429.899994  429.899994  430.100006  429.549988
# 2025-02-11 03:48:00+00:00  429.750000  429.750000  430.000000  429.750000
# 2025-02-11 03:49:00+00:00  430.000000  430.000000  430.299988  429.799988
# ...                               ...         ...         ...         ...
# 2025-02-17 09:55:00+00:00  408.500000  408.500000  408.549988  408.299988
# 2025-02-17 09:56:00+00:00  408.750000  408.750000  408.899994  408.500000
# 2025-02-17 09:57:00+00:00  408.649994  408.649994  408.750000  408.450012
# 2025-02-17 09:58:00+00:00  408.600006  408.600006  408.850006  408.500000
# ...

# %% [markdown]
# * however with yahoo finance we have to keep in mind that for a particualr stock if there is no activity then we will not get the data though its a valid ticker and it exists in the market for that min [when there is no transaction]
# * it is also to be noted that the time that we receive in datetime is in UTC , and gives us the record from 9:15AM IST to 3:29PM IST

# %%
## exporting the data to csv
itc = yf.download(ticker, period='5d', interval='1m')
itc.to_csv("./data-export/exported-itc.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # 3. Getting Pre-market and post-market data

# %%
## US market timings

# pre-market trading time
# 4:00AM EST to 9:29 am EST

# regular market trading time
# 9:30 AM EST to 4:00 PM EST

# post-market trading time
# 4.01PM EST to 8:00PM EST

# %%
# thus for getting the pre and post-market data we have to pass prepost=True . the default value of this parameter is False
# and hence by default the download() gives us only regular-market trading time data
ticker = "GOOG"
yf.download(ticker, period='5d', interval='1m', prepost=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                     Adj Close     Close      High     Low    Open Volume
# Ticker                         GOOG      GOOG      GOOG    GOOG    GOOG   GOOG
# Datetime
# 2025-02-10 09:00:00+00:00  187.0200  187.0200  188.0500  187.02  187.74      0
# 2025-02-10 09:01:00+00:00  187.5800  187.5800  187.5800  187.08  187.09      0
# 2025-02-10 09:02:00+00:00  187.3100  187.3100  187.5700  187.31  187.55      0
# 2025-02-10 09:03:00+00:00  187.4000  187.4000  187.4100  187.15  187.33      0
# 2025-02-10 09:04:00+00:00  187.7000  187.7000  187.7000  187.39  187.39      0
# ...                             ...       ...       ...     ...     ...    ...
# 2025-02-15 00:55:00+00:00  187.0077  187.0077  187.0600  186.93  187.03      0
# 2025-02-15 00:56:00+00:00  186.9100  186.9100  186.9200  186.91  186.92      0
# 2025-02-15 00:57:00+00:00  186.9800  186.9800  186.9800  186.98  186.98      0
# ...

# %%
# however this is to be noted that this does not work for Indian-market and it gives us only regular-market-hour data
# for indian tickers even if we pass this parameter as True
ticker = "RELIANCE.NS"
yf.download(ticker, period='5d', interval='1m', prepost=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                        Adj Close        Close         High          Low  \
# Ticker                     RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS
# Datetime
# 2025-02-11 03:45:00+00:00  1259.300049  1259.300049  1263.050049  1257.599976
# 2025-02-11 03:46:00+00:00  1258.550049  1258.550049  1259.750000  1257.500000
# 2025-02-11 03:47:00+00:00  1258.949951  1258.949951  1259.599976  1258.199951
# 2025-02-11 03:48:00+00:00  1259.099976  1259.099976  1259.550049  1258.000000
# 2025-02-11 03:49:00+00:00  1258.500000  1258.500000  1259.300049  1258.000000
# ...                                ...          ...          ...          ...
# 2025-02-17 09:55:00+00:00  1225.699951  1225.699951  1225.949951  1225.199951
# 2025-02-17 09:56:00+00:00  1225.949951  1225.949951  1226.250000  1224.699951
# 2025-02-17 09:57:00+00:00  1226.000000  1226.000000  1226.300049  1224.599976
# ...

# %% [markdown]
# # 4. getting company info

# %%
ticker = "GOOG"
google = yf.Ticker(ticker)
google.info
# Out:
# {'address1': '1600 Amphitheatre Parkway',
#  'city': 'Mountain View',
#  'state': 'CA',
#  'zip': '94043',
#  'country': 'United States',
#  'phone': '650-253-0000',
#  'website': 'https://abc.xyz',
#  'industry': 'Internet Content & Information',
#  'industryKey': 'internet-content-information',
#  'industryDisp': 'Internet Content & Information',
#  'sector': 'Communication Services',
#  'sectorKey': 'communication-services',
#  'sectorDisp': 'Communication Services',
# ...

# %%
# from this furthus nested attributes can be drilled down as shown below .
google.info.get('city')
# Out:
# 'Mountain View'

# %%
ticker = "RELIANCE.NS"
reliance = yf.Ticker(ticker)
reliance.info.get('bookValue')
# Out:
# 605.573

# %%
# also to inspect what are the attributes and method availabe to this ticker object we can do 
help(reliance)
# Out:
# Help on Ticker in module yfinance.ticker object:
#
# class Ticker(yfinance.base.TickerBase)
#  |  Ticker(ticker, session=None, proxy=None)
#  |
#  |  Method resolution order:
#  |      Ticker
#  |      yfinance.base.TickerBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, ticker, session=None, proxy=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  option_chain(self, date=None, tz=None)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  actions
#  |
#  |  analyst_price_targets
#  |
#  |  balance_sheet
#  |
#  |  balancesheet
#  |
#  |  calendar
#  |      Returns a dictionary of events, earnings, and dividends for the ticker
#  |
#  |  capital_gains
#  |
#  |  cash_flow
#  |
#  |  cashflow
#  |
#  |  dividends
#  |
#  |  earnings
#  |
#  |  earnings_dates
#  |
# ...

# %% [markdown]
# # 5.  getting dividends and stock-splits

# %% [markdown]
# ## getting dividend and stock-split information

# %%
# since dividends and stock-splits are also called corporate=actions so 
#we can fetch them as shown below
ticker = "RELIANCE.NS"
reliance = yf.Ticker(ticker)
reliance.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1996-05-24 00:00:00+05:30   0.742958           0.0
# 1997-05-16 00:00:00+05:30   0.804871           0.0
# 1997-10-27 00:00:00+05:30   0.000000           2.0
# 1998-05-06 00:00:00+05:30   0.866784           0.0
# 1999-05-07 00:00:00+05:30   0.464348           0.0
# 2000-04-06 00:00:00+05:30   0.495305           0.0
# 2001-04-26 00:00:00+05:30   0.526262           0.0
# 2002-10-23 00:00:00+05:30   1.176349           0.0
# 2003-05-23 00:00:00+05:30   1.238263           0.0
# 2004-05-20 00:00:00+05:30   1.300176           0.0
# 2005-05-12 00:00:00+05:30   0.928697           0.0
# 2006-06-01 00:00:00+05:30   2.476525           0.0
# 2007-03-21 00:00:00+05:30   1.362089           0.0
# 2008-05-08 00:00:00+05:30   1.609741           0.0
# 2009-10-16 00:00:00+05:30   1.609741           0.0
# 2009-11-26 00:00:00+05:30   0.000000           2.0
# 2010-05-10 00:00:00+05:30   3.467135           0.0
# ...

# %% [markdown]
# ## getting only dividend data

# %%
ticker = "RELIANCE.NS"
reliance = yf.Ticker(ticker)
reliance.dividends
# Out:
# Date
# 1996-05-24 00:00:00+05:30    0.742958
# 1997-05-16 00:00:00+05:30    0.804871
# 1998-05-06 00:00:00+05:30    0.866784
# 1999-05-07 00:00:00+05:30    0.464348
# 2000-04-06 00:00:00+05:30    0.495305
# 2001-04-26 00:00:00+05:30    0.526262
# 2002-10-23 00:00:00+05:30    1.176349
# 2003-05-23 00:00:00+05:30    1.238263
# 2004-05-20 00:00:00+05:30    1.300176
# 2005-05-12 00:00:00+05:30    0.928697
# 2006-06-01 00:00:00+05:30    2.476525
# 2007-03-21 00:00:00+05:30    1.362089
# 2008-05-08 00:00:00+05:30    1.609741
# 2009-10-16 00:00:00+05:30    1.609741
# 2010-05-10 00:00:00+05:30    3.467135
# 2011-05-05 00:00:00+05:30    1.981220
# 2012-05-31 00:00:00+05:30    4.210093
# 2013-05-10 00:00:00+05:30    2.228873
# 2014-05-16 00:00:00+05:30    4.705398
# 2015-05-08 00:00:00+05:30    2.476525
# 2016-03-17 00:00:00+05:30    2.600351
# 2017-07-13 00:00:00+05:30    2.724178
# 2018-06-27 00:00:00+05:30    5.943660
# 2019-08-02 00:00:00+05:30    3.219483
# ...

# %% [markdown]
# ## getting only stock-split data

# %%
ticker = "RELIANCE.NS"
reliance = yf.Ticker(ticker)
reliance.splits
# Out:
# Date
# 1997-10-27 00:00:00+05:30    2.0
# 2009-11-26 00:00:00+05:30    2.0
# 2017-09-07 00:00:00+05:30    2.0
# 2024-10-28 00:00:00+05:30    2.0
# Name: Stock Splits, dtype: float64

# %% [markdown]
# ## getting dividend and stock-split info as part of historical data

# %%
# the dividends and stock splits are also sometime referred to as corporate actions
# and in case if we want to get it has part of historical data then we have to pass 
# action=True  to the download method. the value of this parameter is false

ticker = 'GOOG'
yf.download(ticker, period='10y', actions=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close Dividends        High         Low  \
# Ticker            GOOG        GOOG      GOOG        GOOG        GOOG
# Date
# 2015-02-17   26.970778   27.067686       0.0   27.424706   26.980425
# 2015-02-18   26.814770   26.911116       0.0   27.199823   26.801914
# 2015-02-19   26.972267   27.069181       0.0   27.081148   26.826847
# 2015-02-20   26.777504   26.873718       0.0   27.113062   26.716648
# 2015-02-23   26.427725   26.522682       0.0   26.748512   26.398024
# ...                ...         ...       ...         ...         ...
# 2025-02-10  188.199997  188.199997       0.0  189.990005  187.610001
# 2025-02-11  187.070007  187.070007       0.0  188.800003  186.080002
# 2025-02-12  185.429993  185.429993       0.0  186.830002  183.630005
# 2025-02-13  187.880005  187.880005       0.0  187.990005  184.880005
# ...

# %%
#lets verify the same on some indian ticker
ticker = 'ITC.NS'
yf.download(ticker, period='10y', actions=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close Dividends        High         Low  \
# Ticker          ITC.NS      ITC.NS    ITC.NS      ITC.NS      ITC.NS
# Date
# 2015-02-18  195.207993  262.166656       0.0  268.000000  256.666656
# 2015-02-19  193.222397  259.500000       0.0  262.466675  255.733337
# 2015-02-20  196.597900  264.033325       0.0  265.266663  256.233337
# 2015-02-23  193.718781  260.166656       0.0  265.866669  259.500000
# 2015-02-24  196.424164  263.799988       0.0  265.333344  259.100006
# ...                ...         ...       ...         ...         ...
# 2025-02-11  411.799988  418.299988       0.0  430.549988  417.500000
# 2025-02-12  409.899994  409.899994       6.5  413.799988  407.600006
# 2025-02-13  409.700012  409.700012       0.0  413.950012  409.000000
# 2025-02-14  410.250000  410.250000       0.0  416.200012  408.399994
# ...

# %% [markdown]
# so this works equally well for indian symbols

# %% [markdown]
# ### filtering dividends and stock-splits from historical data

# %%
#we can also verify this applying filter on the dataframe
ticker = 'ITC.NS'
itc = yf.download(ticker, period='10y', actions=True)
itc.columns
# Out:
# [*********************100%***********************]  1 of 1 completed
# MultiIndex([(   'Adj Close', 'ITC.NS'),
#             (       'Close', 'ITC.NS'),
#             (   'Dividends', 'ITC.NS'),
#             (        'High', 'ITC.NS'),
#             (         'Low', 'ITC.NS'),
#             (        'Open', 'ITC.NS'),
#             ('Stock Splits', 'ITC.NS'),
#             (      'Volume', 'ITC.NS')],
#            names=['Price', 'Ticker'])

# %%
# filtering records for dividends
itc[itc[('Dividends', 'ITC.NS')]>0].head(5)
# Out:
# Price        Adj Close       Close Dividends        High         Low  \
# Ticker          ITC.NS      ITC.NS    ITC.NS      ITC.NS      ITC.NS
# Date
# 2015-06-03  154.126205  202.933334  4.166667  209.233337  200.399994
# 2016-05-30  181.516235  237.666672  1.333333  239.000000  235.199997
# 2017-06-05  246.112595  317.450012  4.750000  318.250000  313.299988
# 2018-05-25  215.139877  272.299988  5.150000  275.000000  268.750000
# 2019-05-22  241.364578  299.750000  5.750000  302.799988  296.799988
#
# Price             Open Stock Splits    Volume
# Ticker          ITC.NS       ITC.NS    ITC.NS
# Date
# 2015-06-03  209.199997          0.0  20673919
# 2016-05-30  235.600006          0.0   7362553
# 2017-06-05  315.000000          0.0   9482413
# 2018-05-25  272.399994          0.0   9244273
# 2019-05-22  302.149994          0.0  13737694

# %%
# filtering to see only stock-split records
itc[itc[('Stock Splits', 'ITC.NS')]>0].head(5)
# Out:
# Price       Adj Close       Close Dividends    High         Low        Open  \
# Ticker         ITC.NS      ITC.NS    ITC.NS  ITC.NS      ITC.NS      ITC.NS
# Date
# 2016-07-01  192.73053  252.350006       0.0  259.75  242.600006  243.300003
#
# Price      Stock Splits    Volume
# Ticker           ITC.NS    ITC.NS
# Date
# 2016-07-01          1.5  27944232

# %%
#combining condition
itc[(itc[('Dividends', 'ITC.NS')]>0) | (itc[('Stock Splits', 'ITC.NS')]>0)].head(5)
# Out:
# Price        Adj Close       Close Dividends        High         Low  \
# Ticker          ITC.NS      ITC.NS    ITC.NS      ITC.NS      ITC.NS
# Date
# 2015-06-03  154.126205  202.933334  4.166667  209.233337  200.399994
# 2016-05-30  181.516235  237.666672  1.333333  239.000000  235.199997
# 2016-07-01  192.730530  252.350006  0.000000  259.750000  242.600006
# 2017-06-05  246.112595  317.450012  4.750000  318.250000  313.299988
# 2018-05-25  215.139877  272.299988  5.150000  275.000000  268.750000
#
# Price             Open Stock Splits    Volume
# Ticker          ITC.NS       ITC.NS    ITC.NS
# Date
# 2015-06-03  209.199997          0.0  20673919
# 2016-05-30  235.600006          0.0   7362553
# 2016-07-01  243.300003          1.5  27944232
# 2017-06-05  315.000000          0.0   9482413
# 2018-05-25  272.399994          0.0   9244273

# %% [markdown]
# # 6. getting company isin

# %%
ticker = "RELIANCE.NS"
reliance = yf.Ticker(ticker)
reliance.isin
# Out:
# 'INE002A01018'

# %% [markdown]
# # 7. getting company news

# %%
ticker = "RELIANCE.NS"
reliance = yf.Ticker(ticker)
reliance.news
# Out:
# [{'uuid': '5bae878b-d2fa-355a-a8ec-7a65f8b747ae',
#   'title': 'Net Asset Value(s)',
#   'publisher': 'Business Wire',
#   'link': 'https://finance.yahoo.com/news/net-asset-value-150800060.html',
#   'providerPublishTime': 1739804880,
#   'type': 'STORY',
#   'relatedTickers': ['~.L', 'FGBL.L', 'GINC.L']},
#  {'uuid': '825bd085-a7e9-3150-87cc-3ad40a215bf3',
#   'title': 'Schouw & Co. share buy-back programme, week 7 2025',
#   'publisher': 'GlobeNewswire',
#   'link': 'https://finance.yahoo.com/news/schouw-co-share-buy-back-150800630.html',
#   'providerPublishTime': 1739804880,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/yY_Ijvm7kfh8P1ZDIAOGVA--~B/aD0yNDk7dz0xOTIwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/51667de1afe3fbbe1b04a6414436bb64',
#      'width': 1920,
#      'height': 249,
#      'tag': 'original'},
# ...

# %% [markdown]
# # 8. Importing data for multiple stocks

# %%
ticker = ["AAPL","AMZN", "GOOG", "NFLX"]
yf.download(ticker, period='5y')
# Out:
# [*********************100%***********************]  4 of 4 completed
# Price        Adj Close                                            Close  \
# Ticker            AAPL        AMZN        GOOG         NFLX        AAPL
# Date
# 2020-02-18   77.414619  107.783501   75.711464   387.779999   79.750000
# 2020-02-19   78.535782  108.511002   76.061211   386.190002   80.904999
# 2020-02-20   77.730103  107.654999   75.635735   386.000000   80.074997
# 2020-02-21   75.970657  104.798500   73.989647   380.070007   78.262497
# 2020-02-24   72.362030  100.464500   70.825012   368.700012   74.544998
# ...                ...         ...         ...          ...         ...
# 2025-02-10  227.649994  233.139999  188.199997  1027.599976  227.649994
# 2025-02-11  232.619995  232.759995  187.070007  1008.080017  232.619995
# 2025-02-12  236.869995  228.929993  185.429993  1027.310059  236.869995
# 2025-02-13  241.529999  230.369995  187.880005  1043.689941  241.529999
# ...

# %% [markdown]
# ## group by tickers

# %%
# however if we want the data to be grouped by the ticker then we can make use of the group_by parameter
# as shown below 
ticker = ["AAPL","AMZN", "GOOG", "NFLX"]
yf.download(ticker, period='5y', group_by='Tickers')
# note the difference in column arragement  of the below dataframe with the previous
# Out:
# [*********************100%***********************]  4 of 4 completed
# Ticker            AAPL                                                  \
# Price             Open        High         Low       Close   Adj Close
# Date
# 2020-02-18   78.839996   79.937500   78.652496   79.750000   77.414619
# 2020-02-19   80.000000   81.142502   80.000000   80.904999   78.535782
# 2020-02-20   80.657501   81.162498   79.552498   80.074997   77.730103
# 2020-02-21   79.654999   80.112503   77.625000   78.262497   75.970657
# 2020-02-24   74.315002   76.044998   72.307503   74.544998   72.362030
# ...                ...         ...         ...         ...         ...
# 2025-02-10  229.570007  230.589996  227.199997  227.649994  227.649994
# 2025-02-11  228.199997  235.229996  228.130005  232.619995  232.619995
# 2025-02-12  231.199997  236.960007  230.679993  236.869995  236.869995
# 2025-02-13  236.910004  242.339996  235.570007  241.529999  241.529999
# ...

# %% [markdown]
# ## getting only the close prices for multiple tickers in one shot

# %%
ticker = ["AAPL","AMZN", "GOOG", "NFLX"]
yf.download(ticker, period='5y').Close
# Out:
# [*********************100%***********************]  4 of 4 completed
# Ticker            AAPL        AMZN        GOOG         NFLX
# Date
# 2020-02-18   79.750000  107.783501   75.983498   387.779999
# 2020-02-19   80.904999  108.511002   76.334503   386.190002
# 2020-02-20   80.074997  107.654999   75.907501   386.000000
# 2020-02-21   78.262497  104.798500   74.255501   380.070007
# 2020-02-24   74.544998  100.464500   71.079498   368.700012
# ...                ...         ...         ...          ...
# 2025-02-10  227.649994  233.139999  188.199997  1027.599976
# 2025-02-11  232.619995  232.759995  187.070007  1008.080017
# 2025-02-12  236.869995  228.929993  185.429993  1027.310059
# 2025-02-13  241.529999  230.369995  187.880005  1043.689941
# 2025-02-14  244.600006  228.679993  186.869995  1058.599976
#
# [1257 rows x 4 columns]

# %% [markdown]
# ## plotting the close prices

# %%
ticker = ["AAPL","AMZN", "GOOG", "NFLX"]
stocksClosingPrices= yf.download(ticker, period='5y').Close
stocksClosingPrices.plot()
plt.show()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %% [markdown]
# # 9.export import

# %% [markdown]
# ## exporting to csv

# %%
ticker = "AAPL"
aapl = yf.download(ticker)
aapl.to_csv("./data-export/exported-aapl.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## reading from csv

# %%
# in earlier yfinance export formats the below would have worked. 
# pd.read_csv("./data-export/exported-aapl.csv", index_col='Date', parse_dates=['Date'])

## however since the in newer version of yfinance the download() gets a multi-indexed datafame so its read as shown below
pd.read_csv("./data-export/exported-aapl.csv",  index_col=[0], header = [0,1])
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 1980-12-12    0.098726    0.128348    0.128906    0.128348    0.128348
# 1980-12-15    0.093575    0.121652    0.122210    0.121652    0.122210
# 1980-12-16    0.086707    0.112723    0.113281    0.112723    0.113281
# 1980-12-17    0.088853    0.115513    0.116071    0.115513    0.115513
# 1980-12-18    0.091429    0.118862    0.119420    0.118862    0.118862
# ...                ...         ...         ...         ...         ...
# 2025-02-10  227.649994  227.649994  230.589996  227.199997  229.570007
# 2025-02-11  232.619995  232.619995  235.229996  228.130005  228.199997
# 2025-02-12  236.869995  236.869995  236.960007  230.679993  231.199997
# 2025-02-13  241.529999  241.529999  242.339996  235.570007  236.910004
# 2025-02-14  244.600006  244.600006  245.550003  240.990005  241.250000
#
# Price          Volume
# ...

# %%
df = pd.read_csv("./data-export/exported-aapl.csv",  index_col=[0], header = [0,1])
df.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             (    'Close', 'AAPL'),
#             (     'High', 'AAPL'),
#             (      'Low', 'AAPL'),
#             (     'Open', 'AAPL'),
#             (   'Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %% [markdown]
# ## exporting to excel

# %%
ticker = "AAPL"
aapl = yf.download(ticker)
aapl.to_excel("./data-export/exported-aapl.xlsx")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## reading to exported excel

# %%
df = pd.read_excel("./data-export/exported-aapl.xlsx",  index_col=[0], header = [0,1])
df
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 1980-12-12    0.098726    0.128348    0.128906    0.128348    0.128348
# 1980-12-15    0.093575    0.121652    0.122210    0.121652    0.122210
# 1980-12-16    0.086707    0.112723    0.113281    0.112723    0.113281
# 1980-12-17    0.088853    0.115513    0.116071    0.115513    0.115513
# 1980-12-18    0.091429    0.118862    0.119420    0.118862    0.118862
# ...                ...         ...         ...         ...         ...
# 2025-02-10  227.649994  227.649994  230.589996  227.199997  229.570007
# 2025-02-11  232.619995  232.619995  235.229996  228.130005  228.199997
# 2025-02-12  236.869995  236.869995  236.960007  230.679993  231.199997
# 2025-02-13  241.529999  241.529999  242.339996  235.570007  236.910004
# 2025-02-14  244.600006  244.600006  245.550003  240.990005  241.250000
#
# Price          Volume
# ...

# %% [markdown]
# # 10. dictionary > series > frames

# %%
ticker = "AAPL"
aapl = yf.Ticker(ticker)
aapl.info #note that we recieve the info in a dictionary format
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
# now lets convert this to a series
pd.Series(aapl.info)
# Out:
# address1             One Apple Park Way
# city                          Cupertino
# state                                CA
# zip                               95014
# country                   United States
#                             ...
# grossMargins                    0.46519
# ebitdaMargins                   0.34706
# operatingMargins                0.34459
# financialCurrency                   USD
# trailingPegRatio                 2.2639
# Length: 128, dtype: object

# %%
#lets convert this series to a frame now
# in other words this will be converted to a row in a dataframe have 132 colums
df = pd.Series(aapl.info, name = "AAPL").to_frame()
df
# Out:
#                                  AAPL
# address1           One Apple Park Way
# city                        Cupertino
# state                              CA
# zip                             95014
# country                 United States
# ...                               ...
# grossMargins                  0.46519
# ebitdaMargins                 0.34706
# operatingMargins              0.34459
# financialCurrency                 USD
# trailingPegRatio               2.2639
#
# [128 rows x 1 columns]

# %%
# thus to convert it into a row we have to transpose this as show below
df = pd.Series(aapl.info, name = "AAPL").to_frame().T
df
# Out:
#                 address1       city state    zip        country  \
# AAPL  One Apple Park Way  Cupertino    CA  95014  United States
#
#                phone                website              industry  \
# AAPL  (408) 996-1010  https://www.apple.com  Consumer Electronics
#
#                industryKey          industryDisp  ...  grossProfits  \
# AAPL  consumer-electronics  Consumer Electronics  ...  184102993920
#
#      freeCashflow operatingCashflow earningsGrowth revenueGrowth grossMargins  \
# AAPL  93833871360      108293996544          0.101          0.04      0.46519
#
#      ebitdaMargins operatingMargins financialCurrency trailingPegRatio
# AAPL       0.34706          0.34459               USD           2.2639
#
# [1 rows x 128 columns]

# %%
#now lets apply the same apporoach on multiple ticker. thus each ticker will a row in our  dataframe.
ticker = ["AAPL","GOOG","META"]
for i in ticker:
    df.loc["{}".format(i)] = pd.Series(yf.Ticker(i).info)
df
# Out:
#                        address1           city state    zip        country  \
# AAPL         One Apple Park Way      Cupertino    CA  95014  United States
# GOOG  1600 Amphitheatre Parkway  Mountain View    CA  94043  United States
# META                 1 Meta Way     Menlo Park    CA  94025  United States
#
#                phone                  website                        industry  \
# AAPL  (408) 996-1010    https://www.apple.com            Consumer Electronics
# GOOG    650-253-0000          https://abc.xyz  Internet Content & Information
# META    650 543 4800  https://investor.fb.com  Internet Content & Information
#
#                        industryKey                    industryDisp  ...  \
# AAPL          consumer-electronics            Consumer Electronics  ...
# GOOG  internet-content-information  Internet Content & Information  ...
# META  internet-content-information  Internet Content & Information  ...
#
# ...

# %% [markdown]
# # 11. earnings

# %% [markdown]
# ## seeing annual income statement

# %%
ticker = "AAPL"
aapl = yf.Ticker(ticker)

## earnings . however this has been depricated 
#aapl.earnings

##now yfinance suggests using
aapl.income_stmt
# Out:
#                                                         2024-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                           0.241
# Normalized EBITDA                                   134661000000.0
# Net Income From Continuing Operation Net Minori...   93736000000.0
# Reconciled Depreciation                              11445000000.0
# Reconciled Cost Of Revenue                          210352000000.0
# EBITDA                                              134661000000.0
# EBIT                                                123216000000.0
# Net Interest Income                                            NaN
# Interest Expense                                               NaN
# Interest Income                                                NaN
# Normalized Income                                    93736000000.0
# Net Income From Continuing And Discontinued Ope...   93736000000.0
# ...

# %% [markdown]
# ## seeing quarterly income statements

# %%
#for getting quarterly income statement 
aapl.quarterly_income_stmt
# Out:
#                                                         2024-12-31  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                            0.21
# Normalized EBITDA                                    45912000000.0
# Net Income From Continuing Operation Net Minori...   36330000000.0
# Reconciled Depreciation                               3080000000.0
# Reconciled Cost Of Revenue                           66025000000.0
# EBITDA                                               45912000000.0
# EBIT                                                 42832000000.0
# Net Interest Income                                            NaN
# Interest Expense                                               NaN
# Interest Income                                                NaN
# Normalized Income                                    36330000000.0
# Net Income From Continuing And Discontinued Ope...   36330000000.0
# ...

# %% [markdown]
# # 12. calendar

# %%
ticker = "AAPL"
aapl = yf.Ticker(ticker)
aapl.calendar
# Out:
# {'Dividend Date': datetime.date(2025, 2, 13),
#  'Ex-Dividend Date': datetime.date(2025, 2, 10),
#  'Earnings Date': [datetime.date(2025, 4, 30), datetime.date(2025, 5, 5)],
#  'Earnings High': 1.67,
#  'Earnings Low': 1.5,
#  'Earnings Average': 1.61696,
#  'Revenue High': 97716000000,
#  'Revenue Low': 89370000000,
#  'Revenue Average': 94206162880}

# %%
ticker = "ITC.NS"
itc = yf.Ticker(ticker)
itc.calendar
# Out:
# {'Ex-Dividend Date': datetime.date(2025, 2, 12),
#  'Earnings Date': [datetime.date(2025, 2, 6)],
#  'Earnings High': 4.9,
#  'Earnings Low': 3.8,
#  'Earnings Average': 4.35,
#  'Revenue High': 179300000000,
#  'Revenue Low': 179300000000,
#  'Revenue Average': 179300000000}

# %% [markdown]
# # 13. stock analyst recommendation

# %%
ticker = "AAPL"
aapl = yf.Ticker(ticker)
aapl.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          7   21    14     2           2
# 1    -1m          8   21    13     2           2
# 2    -2m          8   24    12     1           2
# 3    -3m          8   24    12     1           2

# %%
ticker = "ITC.NS"
itc = yf.Ticker(ticker)
itc.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         11   21     3     0           2
# 1    -1m         10   22     3     0           2
# 2    -2m         11   20     2     0           2
# 3    -3m         11   20     2     0           2

# %% [markdown]
# # 14 getting stock options data

# %%
ticker = "AAPL"
aapl = yf.Ticker(ticker)
aapl.options
# Out:
# ('2025-02-21',
#  '2025-02-28',
#  '2025-03-07',
#  '2025-03-14',
#  '2025-03-21',
#  '2025-03-28',
#  '2025-04-04',
#  '2025-04-17',
#  '2025-05-16',
#  '2025-06-20',
#  '2025-07-18',
#  '2025-08-15',
#  '2025-09-19',
#  '2025-10-17',
#  '2025-12-19',
#  '2026-01-16',
#  '2026-03-20',
#  '2026-06-18',
#  '2026-12-18',
#  '2027-01-15',
#  '2027-06-17')

# %%
ticker = "RELIANCE.NS"
reliance = yf.Ticker(ticker)
reliance.options
# Out:
# ()

# %%
ticker = "AAPL"
aapl = yf.Ticker(ticker)
aapl.option_chain()
# Out:
# Options(calls=         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL250221C00100000 2025-02-12 18:40:34+00:00   100.0     135.70  144.00
# 1   AAPL250221C00105000 2024-12-27 16:14:26+00:00   105.0     149.85  131.30
# 2   AAPL250221C00110000 2025-02-11 19:07:05+00:00   110.0     123.80  134.00
# 3   AAPL250221C00115000 2025-01-27 16:32:05+00:00   115.0     113.65  128.95
# 4   AAPL250221C00120000 2025-01-28 18:41:22+00:00   120.0     118.95  124.00
# ..                  ...                       ...     ...        ...     ...
# 66  AAPL250221C00360000 2025-01-30 17:52:42+00:00   360.0       0.01    0.00
# 67  AAPL250221C00365000 2025-01-29 14:30:06+00:00   365.0       0.02    0.00
# 68  AAPL250221C00370000 2025-01-28 19:48:15+00:00   370.0       0.01    0.00
# 69  AAPL250221C00375000 2025-01-28 19:27:14+00:00   375.0       0.01    0.00
# 70  AAPL250221C00380000 2025-02-03 18:35:01+00:00   380.0       0.01    0.00
#
# ...

# %%
ticker = "RELIANCE.NS"
reliance = yf.Ticker(ticker)
reliance.option_chain()
# Out:
# Options(calls=None, puts=None, underlying=None)

# %% [markdown]
# ## to get option chain for a particular date

# %%
ticker = "AAPL"
aapl = yf.Ticker(ticker)
aaplOptions = aapl.option_chain('2025-02-28') #here we have to pass an upcoming option chain expiry date
aaplOptions
# Out:
# Options(calls=         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL250228C00110000 2025-01-21 19:20:02+00:00   110.0     111.67  133.55
# 1   AAPL250228C00140000 2025-02-06 20:58:29+00:00   140.0      93.57  103.60
# 2   AAPL250228C00145000 2025-02-11 15:05:42+00:00   145.0      86.52   98.80
# 3   AAPL250228C00150000 2025-02-03 15:23:26+00:00   150.0      78.36   94.00
# 4   AAPL250228C00165000 2025-02-10 14:51:51+00:00   165.0      64.94   79.05
# 5   AAPL250228C00170000 2025-02-10 16:38:31+00:00   170.0      59.56   73.60
# 6   AAPL250228C00175000 2025-02-11 16:19:55+00:00   175.0      59.40   69.25
# 7   AAPL250228C00180000 2025-02-14 19:30:44+00:00   180.0      64.45   64.55
# 8   AAPL250228C00185000 2025-02-14 19:43:59+00:00   185.0      59.68   59.35
# 9   AAPL250228C00190000 2025-02-14 18:21:08+00:00   190.0      54.55   54.60
# 10  AAPL250228C00195000 2025-02-14 15:16:14+00:00   195.0      50.05   49.00
# ...

# %%
# to see only call related data for this option
aaplOptions.calls
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL250228C00110000 2025-01-21 19:20:02+00:00   110.0     111.67  133.55
# 1   AAPL250228C00140000 2025-02-06 20:58:29+00:00   140.0      93.57  103.60
# 2   AAPL250228C00145000 2025-02-11 15:05:42+00:00   145.0      86.52   98.80
# 3   AAPL250228C00150000 2025-02-03 15:23:26+00:00   150.0      78.36   94.00
# 4   AAPL250228C00165000 2025-02-10 14:51:51+00:00   165.0      64.94   79.05
# 5   AAPL250228C00170000 2025-02-10 16:38:31+00:00   170.0      59.56   73.60
# 6   AAPL250228C00175000 2025-02-11 16:19:55+00:00   175.0      59.40   69.25
# 7   AAPL250228C00180000 2025-02-14 19:30:44+00:00   180.0      64.45   64.55
# 8   AAPL250228C00185000 2025-02-14 19:43:59+00:00   185.0      59.68   59.35
# 9   AAPL250228C00190000 2025-02-14 18:21:08+00:00   190.0      54.55   54.60
# 10  AAPL250228C00195000 2025-02-14 15:16:14+00:00   195.0      50.05   49.00
# ...

# %%
aaplOptions.puts
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   AAPL250228P00100000 2025-02-03 14:30:11+00:00   100.0       0.03   0.00
# 1   AAPL250228P00110000 2025-01-28 15:46:17+00:00   110.0       0.03   0.00
# 2   AAPL250228P00120000 2025-01-30 16:03:24+00:00   120.0       0.03   0.00
# 3   AAPL250228P00130000 2025-02-13 16:36:49+00:00   130.0       0.01   0.00
# 4   AAPL250228P00140000 2025-02-13 20:18:11+00:00   140.0       0.01   0.00
# 5   AAPL250228P00145000 2025-02-12 14:43:27+00:00   145.0       0.01   0.00
# 6   AAPL250228P00150000 2025-02-12 16:30:56+00:00   150.0       0.02   0.00
# 7   AAPL250228P00155000 2025-02-14 18:02:01+00:00   155.0       0.01   0.00
# 8   AAPL250228P00160000 2025-02-13 20:50:46+00:00   160.0       0.02   0.00
# 9   AAPL250228P00165000 2025-02-13 19:15:27+00:00   165.0       0.02   0.00
# 10  AAPL250228P00170000 2025-02-14 19:47:44+00:00   170.0       0.02   0.02
# ...

# %%
# to see all the other attributes and methods present on this optionChain object
help(aaplOptions)
# Out:
# Help on Options in module yfinance.ticker object:
#
# class Options(builtins.tuple)
#  |  Options(calls, puts, underlying)
#  |
#  |  Options(calls, puts, underlying)
#  |
#  |  Method resolution order:
#  |      Options
#  |      builtins.tuple
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getnewargs__(self) from collections.Options
#  |      Return self as a plain tuple.  Used by copy and pickle.
#  |
#  |  __repr__(self) from collections.Options
#  |      Return a nicely formatted representation string
#  |
#  |  _asdict(self) from collections.Options
#  |      Return a new dict which maps field names to their values.
#  |
#  |  _replace(self, /, **kwds) from collections.Options
#  |      Return a new Options object replacing specified fields with new values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  _make(iterable) from collections.Options
# ...

# %% [markdown]
# # 15. finding share-holding information

# %%
ticker = "TSLA"
tesla = yf.Ticker(ticker)

tesla.major_holders
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.12965
# institutionsPercentHeld          0.49247
# institutionsFloatPercentHeld     0.56583
# institutionsCount             4614.00000

# %%
tesla.institutional_holders
# Out:
#   Date Reported                             Holder  pctHeld     Shares  \
# 0    2023-06-30                 Vanguard Group Inc   0.0701  222486933
# 1    2023-06-30                     Blackrock Inc.   0.0586  185889398
# 2    2023-06-30           State Street Corporation   0.0328  104115390
# 3    2023-06-30      Geode Capital Management, LLC   0.0163   51656526
# 4    2023-06-30            Capital World Investors   0.0133   42272512
# 5    2023-06-30                           FMR, LLC   0.0091   28771552
# 6    2022-12-31  Norges Bank Investment Management   0.0088   28085245
# 7    2023-06-30                     Morgan Stanley   0.0088   27983350
# 8    2023-06-30      Price (T.Rowe) Associates Inc   0.0088   27984161
# 9    2023-06-30          JP Morgan Chase & Company   0.0084   26739940
#
#          Value
# 0  58240404451
# 1  48660267714
# 2  27254285640
# 3  13522128811
# 4  11065675466
# 5   7531529167
# 6   3459540479
# 7   7325201529
# 8   7325413824
# 9   6999714093

# %% [markdown]
# # 16. finding more

# %% [markdown]
# here above we have explored some of important methods and attributes of the ticker objects. however
# it comes with plenty more . we can inspect for more using the help() method which prints all the attributes and
# methods available to the object.

# %%
ticker = "AAPL"
aapl = yf.Ticker(ticker)
help(aapl)
# Out:
# Help on Ticker in module yfinance.ticker object:
#
# class Ticker(yfinance.base.TickerBase)
#  |  Ticker(ticker, session=None, proxy=None)
#  |
#  |  Method resolution order:
#  |      Ticker
#  |      yfinance.base.TickerBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, ticker, session=None, proxy=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  option_chain(self, date=None, tz=None)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  actions
#  |
#  |  analyst_price_targets
#  |
#  |  balance_sheet
#  |
#  |  balancesheet
#  |
#  |  calendar
#  |      Returns a dictionary of events, earnings, and dividends for the ticker
#  |
#  |  capital_gains
#  |
#  |  cash_flow
#  |
#  |  cashflow
#  |
#  |  dividends
#  |
#  |  earnings
#  |
#  |  earnings_dates
#  |
# ...
